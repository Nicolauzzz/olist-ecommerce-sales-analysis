# %% [markdown]
# # Data Cleaning & Preprocessing
#
# ## Overview
#
# This notebook focuses on preparing the Olist Brazilian E-commerce dataset before performing exploratory data analysis.
#
# The cleaning process includes:
#
# - Converting data types
# - Handling missing values
# - Removing duplicate records
# - Merging related datasets
# - Creating new analytical features
#
# The output of this notebook will be used for exploratory data analysis and dashboard development.
#
# ## Objectives
#
# The objectives of this notebook are:
#
# - Improve data quality
# - Standardize data types
# - Handle missing values
# - Remove duplicate records
# - Combine related datasets
# - Prepare an analysis-ready dataset
