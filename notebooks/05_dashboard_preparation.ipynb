# %%
dashboard = sales[
[
    "order_id",
    "purchase_year",
    "purchase_month",
    "customer_city",
    "customer_state",
    "product_category_name_english",
    "payment_type",
    "delivery_days",
    "review_score",
    "total_sales"
]
]

dashboard.to_csv(
    "../data/processed/dashboard_data.csv",
    index=False
)
